# %% [markdown]
# ## Introduction
# Using dlib to extract only the important mouth-area.

# %%
import cv2
import numpy as np
import os
import sys
import dlib
import pandas as pd
from matplotlib import pyplot as plt

# %%
#use SHORT_TEST for fast testing of only one entry
SHORT_TEST = False
detector = dlib.get_frontal_face_detector()
predictor = dlib.shape_predictor("../input/miraclvc1/shape_predictor_68_face_landmarks.dat")

# %%
def get_rect(shape):
    rw = 0
    rh = 0
    rx = 65535
    ry = 65535
    for (x,y) in shape:
        rw = max(rw,x)
        rh = max(rh,y)
        rx = min(rx,x)
        ry = min(ry,y)
    return (rx,ry,rw-rx,rh-ry)
def shape_to_np(shape, dtype="int"):
    # initialize the list of (x, y)-coordinates
    coords = np.zeros((shape.num_parts, 2), dtype=dtype)

    # loop over all facial landmarks and convert them
    # to a 2-tuple of (x, y)-coordinates
    for i in range(0, shape.num_parts):
        coords[i] = (shape.part(i).x, shape.part(i).y)

    # return the list of (x, y)-coordinates
    return coords

# %%
inpDir = '../input/miraclvc1/dataset/dataset'
person = {}
img = None
mouth = None
firstImg = None
firstPerson = None
firstSentenceId = None
firstSentenceId2 = None
ratio = 1.0/2.0
pi = 0
linpDir = os.listdir(inpDir)
for personStr in linpDir:
    pi += 1
    print("person: %s [%d/%d]" % (personStr,pi,len(linpDir)))
    person[personStr] = {}
    personFolder = '%s/%s/phrases' % (inpDir,personStr)
    lpersonFolder = os.listdir(personFolder)
    si = 0
    for sentenceId in lpersonFolder:
        si += 1
        person[personStr][sentenceId] = {}
        print("reading sentence %s for person %s [%d/%d,%d/%d]" % (sentenceId,personStr,si,len(lpersonFolder),pi,len(linpDir)))
        sentenceFolder = '%s/%s' % (personFolder,sentenceId)
        for sentenceId2 in os.listdir(sentenceFolder):
            sentenceFolder2 = '%s/%s/%s' % (personFolder,sentenceId,sentenceId2)
            person[personStr][sentenceId][sentenceId2] = {}
            for frame in os.listdir(sentenceFolder2):
                file = "%s/%s" % (sentenceFolder2,frame)
                if(not os.path.isfile(file)):
                    print("%s does not exist" % file)
                    sys.exit(1)
                if(frame[0:5] != "color"):
                    # skip depth data
                    # kinda reminds me on the song "War" of Edwin Starr
                    continue
                frame = frame[6:-4]
                #print("reading file: %s" % file)
                img = cv2.imread(file)
                img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
                #speed up detector by resizing first
                img2 = cv2.resize(img, None, fx=ratio, fy=ratio)

                
                #detects whole face
                rects = detector(img2, 1)
                if len(rects) == 0:
                    print("error finding head at file: %s" % file)
                    continue
                rects[0] = dlib.scale_rect(rects[0],1/ratio)
                shape = predictor(image=img,box=rects[0])
                shape = shape_to_np(shape)
                
                #indices from 48 to 67 are for mouth
                shape = [shape[x] for x in range(48,68)]
                (x, y, w, h) = get_rect(shape)

                for s in shape:
                    s[0] -= x
                    s[1] -= y
                
                person[personStr][sentenceId][sentenceId2][frame] = {}
                if firstImg is None:
                    firstImg = img
                    firstPerson = personStr
                    firstSentenceId = sentenceId
                    firstSentenceId2 = sentenceId2
                if ((firstPerson == personStr) and (firstSentenceId == sentenceId) and (firstSentenceId2 == sentenceId2)):
                    mouth = img[y:y+h, x:x+w].copy()
                    # sadly we do not have enough time to copy every picture, so only copy first person
                    print("filling: person[%s][%s][%s][%s] with shapes %d" % (personStr,sentenceId,sentenceId2,frame,len(shape)))
                    person[personStr][sentenceId][sentenceId2][frame]["mouth"] = mouth
                
                person[personStr][sentenceId][sentenceId2][frame]["shape"] = shape
            
        #for now just one sentence
        if SHORT_TEST:
            break
    #for now just one person
    if SHORT_TEST:
        break
# Out:
# person: F05 [1/15]
# reading sentence 07 for person F05 [1/10,1/15]
# filling: person[F05][07][07][008] with shapes 20
# filling: person[F05][07][07][002] with shapes 20
# filling: person[F05][07][07][005] with shapes 20
# filling: person[F05][07][07][006] with shapes 20
# filling: person[F05][07][07][012] with shapes 20
# filling: person[F05][07][07][013] with shapes 20
# filling: person[F05][07][07][011] with shapes 20
# filling: person[F05][07][07][016] with shapes 20
# filling: person[F05][07][07][010] with shapes 20
# filling: person[F05][07][07][015] with shapes 20
# filling: person[F05][07][07][004] with shapes 20
# filling: person[F05][07][07][001] with shapes 20
# filling: person[F05][07][07][007] with shapes 20
# filling: person[F05][07][07][014] with shapes 20
# filling: person[F05][07][07][009] with shapes 20
# filling: person[F05][07][07][003] with shapes 20
# reading sentence 10 for person F05 [2/10,1/15]
# reading sentence 05 for person F05 [3/10,1/15]
# reading sentence 06 for person F05 [4/10,1/15]
# reading sentence 02 for person F05 [5/10,1/15]
# reading sentence 04 for person F05 [6/10,1/15]
# reading sentence 08 for person F05 [7/10,1/15]
# reading sentence 09 for person F05 [8/10,1/15]
# reading sentence 03 for person F05 [9/10,1/15]
# reading sentence 01 for person F05 [10/10,1/15]
# person: F11 [2/15]
# reading sentence 07 for person F11 [1/10,2/15]
# reading sentence 10 for person F11 [2/10,2/15]
# reading sentence 05 for person F11 [3/10,2/15]
# reading sentence 06 for person F11 [4/10,2/15]
# reading sentence 02 for person F11 [5/10,2/15]
# reading sentence 04 for person F11 [6/10,2/15]
# reading sentence 08 for person F11 [7/10,2/15]
# reading sentence 09 for person F11 [8/10,2/15]
# reading sentence 03 for person F11 [9/10,2/15]
# reading sentence 01 for person F11 [10/10,2/15]
# person: M02 [3/15]
# reading sentence 07 for person M02 [1/10,3/15]
# reading sentence 10 for person M02 [2/10,3/15]
# reading sentence 05 for person M02 [3/10,3/15]
# reading sentence 06 for person M02 [4/10,3/15]
# reading sentence 02 for person M02 [5/10,3/15]
# reading sentence 04 for person M02 [6/10,3/15]
# reading sentence 08 for person M02 [7/10,3/15]
# reading sentence 09 for person M02 [8/10,3/15]
# reading sentence 03 for person M02 [9/10,3/15]
# reading sentence 01 for person M02 [10/10,3/15]
# person: F02 [4/15]
# reading sentence 07 for person F02 [1/10,4/15]
# reading sentence 10 for person F02 [2/10,4/15]
# reading sentence 05 for person F02 [3/10,4/15]
# reading sentence 06 for person F02 [4/10,4/15]
# reading sentence 02 for person F02 [5/10,4/15]
# reading sentence 04 for person F02 [6/10,4/15]
# reading sentence 08 for person F02 [7/10,4/15]
# reading sentence 09 for person F02 [8/10,4/15]
# reading sentence 03 for person F02 [9/10,4/15]
# reading sentence 01 for person F02 [10/10,4/15]
# person: F07 [5/15]
# reading sentence 07 for person F07 [1/10,5/15]
# reading sentence 10 for person F07 [2/10,5/15]
# reading sentence 05 for person F07 [3/10,5/15]
# reading sentence 06 for person F07 [4/10,5/15]
# reading sentence 02 for person F07 [5/10,5/15]
# reading sentence 04 for person F07 [6/10,5/15]
# reading sentence 08 for person F07 [7/10,5/15]
# reading sentence 09 for person F07 [8/10,5/15]
# reading sentence 03 for person F07 [9/10,5/15]
# reading sentence 01 for person F07 [10/10,5/15]
# person: M04 [6/15]
# reading sentence 07 for person M04 [1/10,6/15]
# reading sentence 10 for person M04 [2/10,6/15]
# reading sentence 05 for person M04 [3/10,6/15]
# reading sentence 06 for person M04 [4/10,6/15]
# reading sentence 02 for person M04 [5/10,6/15]
# reading sentence 04 for person M04 [6/10,6/15]
# reading sentence 08 for person M04 [7/10,6/15]
# reading sentence 09 for person M04 [8/10,6/15]
# reading sentence 03 for person M04 [9/10,6/15]
# reading sentence 01 for person M04 [10/10,6/15]
# person: F09 [7/15]
# reading sentence 07 for person F09 [1/10,7/15]
# reading sentence 10 for person F09 [2/10,7/15]
# reading sentence 05 for person F09 [3/10,7/15]
# reading sentence 06 for person F09 [4/10,7/15]
# reading sentence 02 for person F09 [5/10,7/15]
# reading sentence 04 for person F09 [6/10,7/15]
# reading sentence 08 for person F09 [7/10,7/15]
# reading sentence 09 for person F09 [8/10,7/15]
# reading sentence 03 for person F09 [9/10,7/15]
# reading sentence 01 for person F09 [10/10,7/15]
# person: F04 [8/15]
# reading sentence 07 for person F04 [1/10,8/15]
# reading sentence 10 for person F04 [2/10,8/15]
# reading sentence 05 for person F04 [3/10,8/15]
# reading sentence 06 for person F04 [4/10,8/15]
# reading sentence 02 for person F04 [5/10,8/15]
# error finding head at file: ../input/miraclvc1/dataset/dataset/F04/phrases/02/04/color_009.jpg
# reading sentence 04 for person F04 [6/10,8/15]
# reading sentence 08 for person F04 [7/10,8/15]
# reading sentence 09 for person F04 [8/10,8/15]
# reading sentence 03 for person F04 [9/10,8/15]
# reading sentence 01 for person F04 [10/10,8/15]
# person: F06 [9/15]
# reading sentence 07 for person F06 [1/10,9/15]
# reading sentence 10 for person F06 [2/10,9/15]
# reading sentence 05 for person F06 [3/10,9/15]
# reading sentence 06 for person F06 [4/10,9/15]
# reading sentence 02 for person F06 [5/10,9/15]
# reading sentence 04 for person F06 [6/10,9/15]
# reading sentence 08 for person F06 [7/10,9/15]
# reading sentence 09 for person F06 [8/10,9/15]
# reading sentence 03 for person F06 [9/10,9/15]
# reading sentence 01 for person F06 [10/10,9/15]
# person: M07 [10/15]
# reading sentence 07 for person M07 [1/10,10/15]
# reading sentence 10 for person M07 [2/10,10/15]
# reading sentence 05 for person M07 [3/10,10/15]
# reading sentence 06 for person M07 [4/10,10/15]
# reading sentence 02 for person M07 [5/10,10/15]
# reading sentence 04 for person M07 [6/10,10/15]
# reading sentence 08 for person M07 [7/10,10/15]
# reading sentence 09 for person M07 [8/10,10/15]
# reading sentence 03 for person M07 [9/10,10/15]
# reading sentence 01 for person M07 [10/10,10/15]
# person: F08 [11/15]
# reading sentence 07 for person F08 [1/10,11/15]
# reading sentence 10 for person F08 [2/10,11/15]
# reading sentence 05 for person F08 [3/10,11/15]
# reading sentence 06 for person F08 [4/10,11/15]
# reading sentence 02 for person F08 [5/10,11/15]
# reading sentence 04 for person F08 [6/10,11/15]
# reading sentence 08 for person F08 [7/10,11/15]
# reading sentence 09 for person F08 [8/10,11/15]
# reading sentence 03 for person F08 [9/10,11/15]
# reading sentence 01 for person F08 [10/10,11/15]
# person: F01 [12/15]
# reading sentence 07 for person F01 [1/10,12/15]
# reading sentence 10 for person F01 [2/10,12/15]
# reading sentence 05 for person F01 [3/10,12/15]
# reading sentence 06 for person F01 [4/10,12/15]
# reading sentence 02 for person F01 [5/10,12/15]
# reading sentence 04 for person F01 [6/10,12/15]
# reading sentence 08 for person F01 [7/10,12/15]
# reading sentence 09 for person F01 [8/10,12/15]
# reading sentence 03 for person F01 [9/10,12/15]
# reading sentence 01 for person F01 [10/10,12/15]
# person: M01 [13/15]
# reading sentence 07 for person M01 [1/10,13/15]
# reading sentence 10 for person M01 [2/10,13/15]
# error finding head at file: ../input/miraclvc1/dataset/dataset/M01/phrases/10/01/color_007.jpg
# reading sentence 05 for person M01 [3/10,13/15]
# reading sentence 06 for person M01 [4/10,13/15]
# reading sentence 02 for person M01 [5/10,13/15]
# reading sentence 04 for person M01 [6/10,13/15]
# reading sentence 08 for person M01 [7/10,13/15]
# error finding head at file: ../input/miraclvc1/dataset/dataset/M01/phrases/08/09/color_007.jpg
# error finding head at file: ../input/miraclvc1/dataset/dataset/M01/phrases/08/09/color_003.jpg
# reading sentence 09 for person M01 [8/10,13/15]
# error finding head at file: ../input/miraclvc1/dataset/dataset/M01/phrases/09/09/color_008.jpg
# error finding head at file: ../input/miraclvc1/dataset/dataset/M01/phrases/09/09/color_007.jpg
# error finding head at file: ../input/miraclvc1/dataset/dataset/M01/phrases/09/09/color_009.jpg
# reading sentence 03 for person M01 [9/10,13/15]
# reading sentence 01 for person M01 [10/10,13/15]
# person: M08 [14/15]
# reading sentence 07 for person M08 [1/10,14/15]
# reading sentence 10 for person M08 [2/10,14/15]
# reading sentence 05 for person M08 [3/10,14/15]
# reading sentence 06 for person M08 [4/10,14/15]
# reading sentence 02 for person M08 [5/10,14/15]
# reading sentence 04 for person M08 [6/10,14/15]
# reading sentence 08 for person M08 [7/10,14/15]
# reading sentence 09 for person M08 [8/10,14/15]
# reading sentence 03 for person M08 [9/10,14/15]
# reading sentence 01 for person M08 [10/10,14/15]
# person: F10 [15/15]
# reading sentence 07 for person F10 [1/10,15/15]
# reading sentence 10 for person F10 [2/10,15/15]
# reading sentence 05 for person F10 [3/10,15/15]
# reading sentence 06 for person F10 [4/10,15/15]
# reading sentence 02 for person F10 [5/10,15/15]
# reading sentence 04 for person F10 [6/10,15/15]
# reading sentence 08 for person F10 [7/10,15/15]
# reading sentence 09 for person F10 [8/10,15/15]
# reading sentence 03 for person F10 [9/10,15/15]
# reading sentence 01 for person F10 [10/10,15/15]

# %%
COLS = 3
plt.figure(figsize=(10,20))
plt.subplot(10,COLS,1)
plt.imshow(firstImg,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
for i in range(1,10):
    id = '%03d' % i
    if not id in person[firstPerson][firstSentenceId][firstSentenceId2]:
        print("%s not found!" % id)
    else:
        mouth = person[firstPerson][firstSentenceId][firstSentenceId2][id]["mouth"]
        shape = person[firstPerson][firstSentenceId][firstSentenceId2][id]["shape"]
        plt.subplot(10,COLS,COLS+1+(i-1)*COLS)
        plt.imshow(mouth,cmap = 'gray')
        plt.title('Mouth Image')
        plt.xticks([])
        plt.yticks([])
        
        mouthEdge = np.ones_like(mouth)
        plt.subplot(10,COLS,COLS+2+(i-1)*COLS)
        for (x, y) in shape:
            cv2.circle(mouthEdge, (x, y), 1, (0, 0, 255), -1)
        plt.imshow(mouthEdge,cmap = 'gray')
        plt.title('Mouth Image Edge')
        plt.xticks([])
        plt.yticks([])

        both = np.copy(mouth)
        plt.subplot(10,COLS,COLS+3+(i-1)*COLS)
        for (x, y) in shape:
            cv2.circle(both, (x, y), 1, (0, 0, 255), -1)
        plt.imshow(both,cmap = 'gray')
        plt.title('Both')
        plt.xticks([])
        plt.yticks([])
plt.show()

# %% [markdown]
# ## Store shapes as csv-output
#
# This output can be then used in another kernel.

# %%
fileCount = 0
for p in person.keys():
    for sentenceId in person[p].keys():
        shapes = []
        for sentenceId2 in person[p][sentenceId].keys():
            for id in person[p][sentenceId][sentenceId2].keys():
                shape = person[p][sentenceId][sentenceId2][id]["shape"]
                for (x,y) in shape:
                    shapes.append((id,sentenceId2,x,y))
        df = pd.DataFrame(data = shapes,columns = ['id','sentenceId2','x','y'])
        path = "%s/phrases/%s" % (p,sentenceId)
        try:
            os.makedirs(path)
        except FileExistsError as e:
            pass
        filename = "shapes.csv"
        csvPath = "%s/%s" % (path,filename)
        print("saving %s" % csvPath)
        df.to_csv(csvPath,index = False)
        
        
       
        fileCount += 1
#total fileCount needs to be below 500
print("fileCount: %d" % fileCount)
